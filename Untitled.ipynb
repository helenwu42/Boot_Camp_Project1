# %%
# Dependencies
import requests
import json
import statistics
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# URL for GET requests to retrieve vehicle data
url = "https://api.iextrading.com/1.0/stock/AAPL/chart/3m"

# %%
# Pretty print JSON for all launchpads
response = requests.get(url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "change": 1.4748,
#         "changeOverTime": 0,
#         "changePercent": 0.805,
#         "close": 184.752,
#         "date": "2018-07-05",
#         "high": 185.7585,
#         "label": "Jul 5, 18",
#         "low": 183.6359,
#         "open": 184.6125,
#         "unadjustedVolume": 16604248,
#         "volume": 16604248,
#         "vwap": 184.8254
#     },
#     {
#         "change": 2.561,
#         "changeOverTime": 0.013861825582402239,
#         "changePercent": 1.386,
#         "close": 187.313,
#         "date": "2018-07-06",
#         "high": 187.7754,
#         "label": "Jul 6, 18",
#         "low": 184.5527,
#         "open": 184.772,
#         "unadjustedVolume": 17485245,
#         "volume": 17485245,
#         "vwap": 186.6864
#     },
#     {
#         "change": 2.6009,
#         "changeOverTime": 0.02793961635056726,
#         "changePercent": 1.389,
#         "close": 189.9139,
#         "date": "2018-07-09",
#         "high": 190.0136,
# ...

# %%
#7 day moving average

week_counter = 0 
avg_counter = 0
series1 = 10
series2 = 7
count = 0  
moving_avg =[]



for x in range(series1):
    
        close = []
        
        for y in range(series2):
            try:
                close.append(response[count]['close'])
                #print(close)
                count = count +1
            
            except:
                print("No value")    
        print(close) 
        avg = statistics.mean(close)   
        moving_avg.append(avg)

print(moving_avg)
# Out:
# [184.752, 187.313, 189.9139, 189.6847, 187.2234, 190.3623, 190.6613]
# [190.2428, 190.7809, 189.7346, 191.2094, 190.7709, 190.9403, 192.3255]
# [194.1391, 193.5312, 190.3125, 189.2463, 189.6249, 200.7958, 206.6652]
# [207.2631, 208.3393, 206.3862, 206.5257, 208.15, 207.53, 208.87]
# [209.75, 210.24, 213.32, 217.58, 215.46, 215.04, 215.05]
# [215.49, 216.16, 217.94, 219.7, 222.98, 225.03, 227.63]
# [228.36, 226.87, 223.1, 221.3, 218.33, 223.85, 221.07]
# [226.41, 223.84, 217.88, 218.24, 218.37, 220.03, 217.66]
# [220.79, 222.19, 220.42, 224.95, 225.74, 227.26, 229.28]
# No value
# No value
# No value
# No value
# [232.07, 227.99, 224.29]
# [188.55865714285716, 190.85777142857143, 194.90214285714285, 207.5806142857143, 213.77714285714285, 220.7042857142857, 223.26857142857142, 220.34714285714287, 224.37571428571428, 228.11666666666667]

# %%
summary = pd.DataFrame({"Moving Average": moving_avg})
summary
# Out:
#    Moving Average
# 0      188.558657
# 1      190.857771
# 2      194.902143
# 3      207.580614
# 4      213.777143
# 5      220.704286
# 6      223.268571
# 7      220.347143
# 8      224.375714
# 9      228.116667

# %%
plt.xlim([0,series1])
plt.plot(moving_avg, marker="o", color="orange", linewidth=1)
plt.show()

# %%
linegrpah = summary.plot.line()
linegrpah.set_xticklabels(range(20))
# Out:
# [Text(0,0,'0'),
#  Text(0,0,'1'),
#  Text(0,0,'2'),
#  Text(0,0,'3'),
#  Text(0,0,'4'),
#  Text(0,0,'5'),
#  Text(0,0,'6'),
#  Text(0,0,'7'),
#  Text(0,0,'8'),
#  Text(0,0,'9')]

# %%
#7 day moving average
   week_counter=0
   avg_counter=0
   #Loop every 7
   If week_counter<8:

       Week.append(Day[average or close])
       week_counter+=1
   moving_Average.append(week.mean())
   avg_counter+=1
   plt.line(moving_average,counter)
   If counter==90:
       Moving_average.pop(0)
       Counter-=1

   #Predict the next day based off sentiment
   #Compare week.mean() to moving_average.mean()

   #Auto adjust parameters based off the accuracy of last predictions
