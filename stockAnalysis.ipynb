# %%
import json
import requests

url = "https://api.iextrading.com/1.0/stock/tsla/chart/1d"
 
response = requests.get(url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "average": 293.085,
#         "changeOverTime": 0,
#         "close": 293,
#         "date": "20181004",
#         "high": 293.91,
#         "label": "09:30 AM",
#         "low": 293,
#         "marketAverage": 293.53,
#         "marketChangeOverTime": 0,
#         "marketClose": 292.75,
#         "marketHigh": 294,
#         "marketLow": 292.504,
#         "marketNotional": 40374707.2276,
#         "marketNumberOfTrades": 476,
#         "marketOpen": 293.95,
#         "marketVolume": 137549,
#         "minute": "09:30",
#         "notional": 124561.25,
#         "numberOfTrades": 5,
#         "open": 293.91,
#         "volume": 425
#     },
#     {
#         "average": 292.26,
#         "changeOverTime": -0.0028148830544039737,
#         "close": 292.26,
#         "date": "20181004",
#         "high": 292.26,
#         "label": "09:31 AM",
#         "low": 292.26,
#         "marketAverage": 292.373,
#         "marketChangeOverTime": -0.003941675467584173,
# ...
